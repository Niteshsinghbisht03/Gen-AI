# %%
import os
os.environ['GOOGLE_API_KEY']='AIzaSyDTVhDtwjkkUI5k-xk3SKnxOl9LF8PzncQ'

# %%
# !pip install -q  langchain-core requests  langchain-google-genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

# %%
#toolcreate

@tool
def multiply(a:int,b:int)->int:
  """Given 2 numbers a and b this tool returns their product"""
  return a*b

# %%
print(multiply.invoke({'a':3,'b':4}))
# Out:
# 12

# %%
multiply.name
# Out:
# 'multiply'

# %%
multiply.description
# Out:
# 'Given 2 numbers a and b this tool returns their product'

# %%
multiply.args
# Out:
# {'a': {'title': 'A', 'type': 'integer'},
#  'b': {'title': 'B', 'type': 'integer'}}

# %%
multiply.args_schema
# Out:
# langchain_core.utils.pydantic.multiply

# %%
#toolbinding

# %%
llm = ChatGoogleGenerativeAI(model='gemini-1.5-pro')

# %%
llm_with_tools=llm.bind_tools([multiply])

# %%
llm_with_tools.invoke("how are you")
# Out:
# AIMessage(content="I'm doing well, thanks for asking! How can I help you today?", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-pro-002', 'safety_ratings': []}, id='run-6b38069f-bfb5-48eb-b6ed-b66333b857ec-0', usage_metadata={'input_tokens': 23, 'output_tokens': 18, 'total_tokens': 41, 'input_token_details': {'cache_read': 0}})

# %%
query = HumanMessage("can you multiply 3 with 200")

# %%
messages = [query]

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 200', additional_kwargs={}, response_metadata={})]

# %%
#tool calling
result = llm_with_tools.invoke(messages)

# %%
messages.append(result)

# %%
 #tool execution
tool_result = multiply.invoke(result.tool_calls[0])

# %%
messages.append(tool_result)

# %%
answer = llm_with_tools.invoke(messages)

# %%
answer.content
# Out:
# 'The product of 3 and 200 is 600.'
